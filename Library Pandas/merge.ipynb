# %%
import pandas as pd

left = pd.DataFrame(
    {
        "key": ["K0", "K1", "K2", "K3"],
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
    }
)


right = pd.DataFrame(
    {
        "key": ["K0", "K1", "K2", "K3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    }
)

# %%
left
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
right
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
result = pd.merge(left, right, on="key")
result
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
left = pd.DataFrame(
    {
        "key1": ["K0", "K0", "K1", "K2"],
        "key2": ["K0", "K1", "K0", "K1"],
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
    }
)


right = pd.DataFrame(
    {
        "key1": ["K0", "K1", "K1", "K2"],
        "key2": ["K0", "K0", "K0", "K0"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    }
)

# %%
left
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
right
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
result = pd.merge(left, right, on=["key1", "key2"])
result
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
Methods = pd.DataFrame([['left', 'LEFT OUTER JOIN', 'Use keys from left frame only'], ['right', 'RIGHT OUTER JOIN', 'Use keys from right frame only'], ['outer', 'FULL OUTER JOIN', 'Use union of keys from both frames'], ['inner', 'INNER JOIN', 'Use intersection of keys from both frames'], ['cross', 'CROSS JOIN', 'Create the cartesian product of rows of both frames']], columns=['Merge method', 'SQL Join Name', 'Description'])
Methods.set_index('Merge method')
# Out:
#                  SQL Join Name  \
# Merge method
# left           LEFT OUTER JOIN
# right         RIGHT OUTER JOIN
# outer          FULL OUTER JOIN
# inner               INNER JOIN
# cross               CROSS JOIN
#
#                                                     Description
# Merge method
# left                              Use keys from left frame only
# right                            Use keys from right frame only
# outer                        Use union of keys from both frames
# inner                 Use intersection of keys from both frames
# cross         Create the cartesian product of rows of both f...

# %%
result = pd.merge(left, right, how="left", on=["key1", "key2"])
result
# Out:
#   key1 key2   A   B    C    D
# 0   K0   K0  A0  B0   C0   D0
# 1   K0   K1  A1  B1  NaN  NaN
# 2   K1   K0  A2  B2   C1   D1
# 3   K1   K0  A2  B2   C2   D2
# 4   K2   K1  A3  B3  NaN  NaN

# %%
result = pd.merge(left, right, how="right", on=["key1", "key2"])
result
# Out:
#   key1 key2    A    B   C   D
# 0   K0   K0   A0   B0  C0  D0
# 1   K1   K0   A2   B2  C1  D1
# 2   K1   K0   A2   B2  C2  D2
# 3   K2   K0  NaN  NaN  C3  D3

# %%
result = pd.merge(left, right, how="outer", on=["key1", "key2"])
result
# Out:
#   key1 key2    A    B    C    D
# 0   K0   K0   A0   B0   C0   D0
# 1   K0   K1   A1   B1  NaN  NaN
# 2   K1   K0   A2   B2   C1   D1
# 3   K1   K0   A2   B2   C2   D2
# 4   K2   K1   A3   B3  NaN  NaN
# 5   K2   K0  NaN  NaN   C3   D3

# %%
result = pd.merge(left, right, how="cross")
result
# Out:
#    key1_x key2_x   A   B key1_y key2_y   C   D
# 0      K0     K0  A0  B0     K0     K0  C0  D0
# 1      K0     K0  A0  B0     K1     K0  C1  D1
# 2      K0     K0  A0  B0     K1     K0  C2  D2
# 3      K0     K0  A0  B0     K2     K0  C3  D3
# 4      K0     K1  A1  B1     K0     K0  C0  D0
# 5      K0     K1  A1  B1     K1     K0  C1  D1
# 6      K0     K1  A1  B1     K1     K0  C2  D2
# 7      K0     K1  A1  B1     K2     K0  C3  D3
# 8      K1     K0  A2  B2     K0     K0  C0  D0
# 9      K1     K0  A2  B2     K1     K0  C1  D1
# 10     K1     K0  A2  B2     K1     K0  C2  D2
# 11     K1     K0  A2  B2     K2     K0  C3  D3
# 12     K2     K1  A3  B3     K0     K0  C0  D0
# 13     K2     K1  A3  B3     K1     K0  C1  D1
# 14     K2     K1  A3  B3     K1     K0  C2  D2
# 15     K2     K1  A3  B3     K2     K0  C3  D3

# %% [markdown]
# If we put ``, indicator=True` on attributes we gonna get _merge column:

# %% [markdown]
# #### The column **“_merge”** will have a Categorical type with the value of “left_only” for observations whose merge key only appears in the left DataFrame, “right_only” for observations whose merge key only appears in the right DataFrame, and “both” if the observation’s merge key is found in both DataFrames.
